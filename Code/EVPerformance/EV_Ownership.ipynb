# %%
# Import the required libraries and dependencies
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_excel("EVOwnership.xlsx")

# %%
df1.head()
# Out:
#   state  taxes  fuel  insurance
# 0    WA    338  1119       1016
# 1    Or   -158  1116       1037
# 2    CA    295  1141       2716
# 3    ID    276  1246        849
# 4    NV     90  1470       1299

# %%
df1.dtypes
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   state      47 non-null     object
#  1   taxes      47 non-null     int64
#  2   fuel       47 non-null     int64
#  3   insurance  47 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB

# %%
plt.scatter(df1['state'], df1['taxes'])
plt.xticks(rotation=90)
plt.tight_layout()
ax = df1.plot(df1['state'], df1['taxes']):(lw=2, colormap='jet', marker='.', markersize=10, title='Increased Cost of Taxes Per State')
# Out:
#   Cell In[35], line 4
#     ax = df1.plot(df1['state'], df1['taxes']):(lw=2, colormap='jet', marker='.', markersize=10, title='Increased Cost of Taxes Per State')
#                                              ^
# SyntaxError: invalid syntax

# %%
plt.scatter(df1['state'], df1['fuel'])
plt.xticks(rotation=90)
plt.tight_layout()

# %%
x_values= df1["state"]
y_values= df1["taxes"]
plt.plot(x_values, y_values)
plt.xticks(rotation=90)
plt.tight_layout()
plt.title("Increased Tax Cost of EV Ownership", fontsize=20)
plt.xlabel("State", fontsize=15)
plt.ylabel("Increased Tax Cost in $", fontsize=15)
plt.tick_params(axis = 'both', which = 'major', labelsize=8)
plt.show()

# %%
df1['taxes'].mean()
# Out:
# 207.68085106382978

# %%
x_values= df1["state"]
y_values= df1["fuel"]
plt.plot(x_values, y_values)
plt.xticks(rotation=90)
plt.tight_layout()
plt.title("Increased Fuel Cost of EV Ownership", fontsize=20)
plt.xlabel("State", fontsize=15)
plt.ylabel("Increased Fuel Cost in $", fontsize=15)
plt.tick_params(axis = 'both', which = 'major', labelsize=8)
plt.show()

# %%
df1['fuel'].mean()
# Out:
# 1071.6808510638298

# %%
x_values= df1["state"]
y_values= df1["insurance"]
plt.plot(x_values, y_values)
plt.xticks(rotation=90)
plt.tight_layout()
plt.title("Increased insurance Cost of EV Ownership", fontsize=20)
plt.xlabel("State", fontsize=15)
plt.ylabel("Increased Insurance Cost in $", fontsize=15)
plt.tick_params(axis = 'both', which = 'major', labelsize=8)
plt.show()

# %%
df1['insurance'].mean()
# Out:
# 1397.0425531914893
